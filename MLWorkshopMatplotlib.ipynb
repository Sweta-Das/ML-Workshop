# %% [markdown]
# <a href="https://colab.research.google.com/github/Sweta-Das/ML-Workshop/blob/main/MLWorkshopMatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
xpts = np.array([0, 6])
ypts = np.array([0, 200])
plt.plot(xpts, ypts)
plt.show()

# %%
xpts1 = np.array([1, 8])
ypts1 = np.array([8, 10])
plt.plot(xpts1, ypts1)
plt.show()

# %%
plt.plot(xpts, ypts)
plt.plot(xpts1, ypts1)
plt.show()

# %%
#Plotting without line
plt.plot(xpts1, ypts1, 'o')
plt.show()

# %%
#Multiple points
xpts = np.array([1, 2, 9 , 10])
ypts = np.array([3, 7, 5, 4])
plt.plot(xpts, ypts, 'o')

# %%
ypts = np.array([3, 7, 5, 4])
plt.plot(ypts, 'o')

# %%
#markers
plt.plot(ypts, '*')

# %%
plt.plot(ypts, 'o--r')

# %%
plt.plot(ypts, '*:g')

# %% [markdown]
# '-' => Solid line
# '--' => Dashed line
# ':' => Dotted line
# '-.' => dashed/dotted line

# %%
plt.plot(ypts, marker = 's')

# %%
plt.plot(ypts, marker = 'h', ms = 10, mec = 'red', mfc = 'blue') # mec = marker edge color, mfc = marker face color

# %%
# Line color, size , style, width
# color (c), size (s), linestyle (ls), linewidth (lw)
plt. plot(ypts, c = 'red', ls = ':', lw = '10')

# %% [markdown]
# MATPLOTLIB titles, labels

# %%
x = np.array([80, 85, 90, 95, 100])
y = np.array([100, 200, 300, 400, 500])
plt.plot(x, y)
plt.title("Student Roll No Vs Steps")
plt.xlabel("Student Roll No.")
plt.ylabel("Student Steps")
# Out:
# Text(0, 0.5, 'Student Steps')

# %%
import matplotlib.font_manager

# %%
x = np.array([80, 85, 90, 95, 100])
y = np.array([100, 200, 300, 400, 500])

font1 = {'family': 'serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'monospace', 'color': 'red', 'size': 10}

plt.title("Student Roll No Vs Steps", fontdict = font1, loc = 'right') # right, left, center
plt.xlabel("Student Roll No.", fontdict = font2)
plt.ylabel("Student Steps", fontdict = font2)

plt.plot(x, y)

# %%
# Grid lines: grid()
plt.plot(x, y)
plt.grid()

# %%
plt.plot(x, y)
plt.grid(axis = 'y')

# %%
plt.plot(x, y)
plt.grid(color='green', linestyle='-.', linewidth = '0.5')

# %%
# subplot()
#plot-1
x = np.array([1, 2, 3, 4])
y = np.array([5, 2, 9, 8])
plt.subplot(1, 2, 1) #row, column, figure no.
plt.plot(x,y)

#plot-2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2, 2)
plt.plot(x, y)

# %%
# subplot()
#plot-1
x = np.array([1, 2, 3, 4])
y = np.array([5, 2, 9, 8])
plt.subplot(1, 2, 1) #row, column, figure no.
plt.plot(x,y)
plt.title("Numbers")

#plot-2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2, 2)
plt.plot(x, y)
plt.title("Strings")

plt.suptitle("Data") # Supertitle
plt.show()

# %%
# Scatter Plots : scatter()
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
plt.scatter(x, y)

# %%
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
plt.scatter(x, y)

x1 = np.array([5, 7, 0, 9, 2, 18, 20, 19, 7])
y1 = np.array([10, 44, 52, 78, 90, 40, 60, 4, 23])

plt.scatter(x1, y1)

# %%
x1 = np.array([5, 7, 0, 9, 2, 18, 20, 19, 7])
y1 = np.array([10, 44, 52, 78, 90, 40, 60, 4, 23])

plt.scatter(x1, y1, color = 'black')

x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
plt.scatter(x, y, color = 'yellow')

# %%
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
colors = np.array(['red', 'magenta', 'yellow', 'green', 'blue', 'black', 'brown', 'pink', 'hotpink'])
plt.scatter(x, y, c=colors)

# %%
# colormap
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
colors = np.array([0, 10, 20, 30, 40, 50, 60, 70, 80])
plt.scatter(x, y, c=colors, cmap = 'Purples')

# %%
# sizes
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
colors = np.array([0, 10, 20, 30, 40, 50, 60, 70, 80])
sizes = np.array([10, 20, 50, 100, 200, 250, 70, 50, 30])
plt.scatter(x, y, c=colors, cmap = 'viridis', s = sizes)

# %%
# Transparency: alpha (0-1)
x = np.array([5, 7, 8, 9, 2, 15, 16, 19, 9])
y = np.array([10, 44, 56, 78, 93, 45, 67, 4, 23])
colors = np.array([0, 10, 20, 30, 40, 50, 60, 70, 80])
sizes = np.array([10, 20, 50, 100, 200, 250, 70, 50, 30])
plt.scatter(x, y, c=colors, cmap = 'viridis', s = sizes, alpha = 0.5)

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c = colors, s= sizes, alpha = 0.5, cmap = 'viridis')
plt.colorbar()
plt.show()

# %%
# Bar plot
x = np.array(["Apples", "Mango", "Grapes", "Banana"])
y = np.array([5, 8, 3, 4])
plt.barh(x, y, color='red', height=0.1)
#plt.bar(x, y, color='red', width=0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
#Histograms: hist()
x= np.random.normal(150, 10, 300) # values = 300, Standard deviation= 10, value concentrated = 150
#print(x)
plt.hist(x)
# Out:
# (array([ 3.,  8., 24., 67., 66., 64., 39., 22.,  6.,  1.]),
#  array([118.38721764, 125.10051469, 131.81381173, 138.52710878,
#         145.24040583, 151.95370288, 158.66699992, 165.38029697,
#         172.09359402, 178.80689107, 185.52018812]),
#  <a list of 10 Patch objects>)

# %%
# Pie Chart: pie()
y = np.array([43, 10, 15, 10])
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3b02bf9710>,
# ...
#  [Text(-0.17645239851730588, 1.0857552905961316, ''),
#   Text(-0.823361820361495, -0.7294349270298246, ''),
#   Text(0.17645244934517845, -1.0857552823357974, ''),
#   Text(1.01197741855979, -0.4311631991776008, '')])

# %%
y = np.array([43, 10, 15, 10])
mlabels = ["BCT", "BEI", "BCA", "BEL"]
plt.pie(y, labels= mlabels, startangle=45)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3b027119d0>,
# ...
#  [Text(-0.8925156162379132, 0.6429742411414769, 'BCT'),
#   Text(-0.06641634321060974, -1.0979931098848164, 'BEI'),
#   Text(0.8925156463377084, -0.6429741993598055, 'BCA'),
#   Text(1.0204545170078523, 0.4106976731347172, 'BEL')])

# %%
y = np.array([43, 10, 15, 10])
mlabels = ["BCT", "BEI", "BCA", "BEL"]
mcolors = ["black", "yellow", "green", "magenta"]
plt.pie(y, labels= mlabels, startangle=45, colors = mcolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3b026ed210>,
# ...
#  [Text(-0.8925156162379132, 0.6429742411414769, 'BCT'),
#   Text(-0.06641634321060974, -1.0979931098848164, 'BEI'),
#   Text(0.8925156463377084, -0.6429741993598055, 'BCA'),
#   Text(1.0204545170078523, 0.4106976731347172, 'BEL')])

# %%
# explode
y = np.array([43, 10, 15, 10])
mlabels = ["BCT", "BEI", "BCA", "BEL"]
mcolors = ["black", "yellow", "green", "magenta"]
mexplode = [0.2, 0.1, 0.3, 0.5]
plt.pie(y, labels= mlabels, startangle=45, colors = mcolors, explode = mexplode, shadow = True)
plt.legend(title = "Departments")

# %%
x = np.random.randint(50, size=(50))
y = np.random.randint(50, size=(50))
sizes = np.random.randint(50, size=(50))
plt.subplot(2,2,1)
plt.scatter(x, y, s=sizes, cmap='Accent', alpha=0.5)

x = np.array(["Cat", "Dog", "Giraffe", "Bat"])
y = np.array([5, 8, 4, 9])
plt.subplot(2,2,2)
plt.bar(x, y, color="pink")

x = np.random.normal(25, 10, 50)
plt.subplot(2,2,3)
plt.hist(x)
# Out:
# (array([5., 5., 3., 9., 6., 7., 8., 4., 2., 1.]),
#  array([ 5.44418995,  9.92662342, 14.40905689, 18.89149036, 23.37392383,
#         27.8563573 , 32.33879078, 36.82122425, 41.30365772, 45.78609119,
#         50.26852466]),
#  <a list of 10 Patch objects>)

# %%
y = np.array([25, 17, 34, 17])
mlabels= ["BCT", "BCA", "BEL", "BCE"]
mcolors = ["black", "blue", "red", "green"]
plt.pie(y, labels = mlabels, colors = mcolors, startangle = 25)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3b0207f350>,
# ...
#  [Text(0.3144945565574656, 1.0540840449867948, 'BCT'),
#   Text(-0.9943055020687784, 0.47048546051472684, 'BCA'),
#   Text(-0.31449445786699365, -1.0540840744318956, 'BEL'),
#   Text(1.0895519219422687, -0.15125015501449401, 'BCE')])

# %%
data = np.random.normal(170, 10, 250)
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
plt.show()

# %%
# Normal Distribution Curve
from scipy.stats import norm
import statistics as st

# Plot between -30 to +30 with 0.1 Steps
x_axis = np.arange(-30, 30, 0.1)
mean = st.mean(x_axis)
sd = st.stdev(x_axis)
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
# Histogram over Normal Distribution curve
data = np.random.normal(170, 10, 250)
mean, std = norm.fit(data)
plt.hist(data, bins=25, density=True, alpha = 0.6, color='b')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
plt.show()
